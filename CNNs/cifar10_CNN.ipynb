# %%
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Activation, Dense, Flatten, Dropout
from keras.utils import to_categorical
from keras.optimizers import SGD
from keras.datasets import cifar10
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix

# %%
import keras.backend
keras.backend.tensorflow_backend._get_available_gpus()
# Out:
# ['/job:localhost/replica:0/task:0/device:GPU:0']

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the CIFAR10 dataset

# %%
(X_train, y_train), (X_test, y_test)  = cifar10.load_data()

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %% [markdown]
#                                  Show some of the images with labels

# %%
def get_label(label_as_np_array, label_dict):

    return label_dict[int(label_as_np_array)]

# %%
def plot_images(count, label_dict):
    list_of_labels = np.random.randint(y_train.shape[0], size=count)
    plt.figure(figsize=(int(1.5)* count, 2 * count))
    plt.tight_layout()

    for i in np.arange(0,count):
        # Subplot
        plt.subplot(count - 3, 3, i + 1, ymargin=1)
        # Label of the image
        label_as_np_array = y_train[list_of_labels[i]]
        plt.title(get_label(label_as_np_array, label_dict)+ '  ' + str(list_of_labels[i]))
        # Show the image
        image_to_show = X_train[list_of_labels[i]]
        plt.imshow(image_to_show)
        
    return plt.show()

# %% [markdown]
#                                               CIFAR10 labels

# %%
cifar10_labels = {
        0:"airplane",
        1:"automobile",
        2:"bird",
        3:"cat",
        4:"deer",
        5:"dog",
        6:"frog",
        7:"horse",
        8:"ship",
        9:"truck"
        }

# %% [markdown]
#                                            Normalize image input
#                                            [0..255] ====> [0..1]

# %%
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %% [markdown]
#                                     Convert labels to one-hot encoding

# %%
plot_images(count=17, label_dict=cifar10_labels)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### AlexNet
#
# INPUT => [CONV => RELU => POOL] * 2 => [CONV => RELU] * 3 => POOL => [FC => RELU => DO] * 2 => SOFTMAX

# %%
def alex_net(batch_size, learning_rate, num_epochs, num_classes, dataset=(X_train, y_train, X_test, y_test)):
    X_train, y_train, X_test, y_test = dataset
    model = Sequential()
    
    # Input => [CONV => RELU => POOL] * 2 => ...
    # First
    model.add(Conv2D(32,(3,3),input_shape = X_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    # Second
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    # ... => [CONV => RELU] * 3
    # First
    model.add(Conv2D(64, (3,3)))
    model.add(Activation("relu"))
    # Second
    model.add(Conv2D(64, (3,3)))
    model.add(Activation("relu"))

    
    # ... => POOL => ...
    model.add(MaxPooling2D(pool_size=(2,2)))
    # ... => [FC => RELU => DO] * 2 => ...
    model.add(Flatten())
    # First
    model.add(Dense(512))
    model.add(Activation("relu"))
    model.add(Dropout(0.5))
    # Second
    model.add(Dense(512))
    model.add(Activation("relu"))
    model.add(Dropout(0.5))
    
    # ... => Softmax => Output
    model.add(Dense(num_classes))
    model.add(Activation("softmax"))
    
    # Compile and train the model
    model.compile(loss='categorical_crossentropy',
                  optimizer=SGD(learning_rate),
                  metrics = ["accuracy"])
    
    model.fit(X_train, y_train, 
              batch_size=batch_size, 
              epochs=num_epochs,
              validation_data=(X_test, y_test),
              shuffle=True)
        
    return model

# %%
def plot_results(model):
    plt.figure(figsize=(20,15))
    
    plt.subplot(221)
    plt.title("Losses")
    plt.grid()
    plt.legend(("Training losses", "Test losses"))
    plt.plot(np.arange(0,len(model.history["loss"])), model.history["loss"])
    plt.plot(np.arange(0,len(model.history["val_loss"])), model.history["val_loss"])
    
    plt.subplot(222)
    plt.title("Accuracy")
    plt.grid()
    plt.legend(("Training Accuracy", "Test Accuracy"))
    plt.plot(np.arange(0,len(model.history["acc"])), model.history["acc"])
    plt.plot(np.arange(0,len(model.history["val_acc"])), model.history["val_acc"])
    return plt.show()

# %%
t = alex_net(batch_size=32, learning_rate=0.003, num_epochs=100, num_classes=10, dataset=(X_train, y_train, X_test, y_test))
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 8s 154us/step - loss: 2.3017 - acc: 0.1087 - val_loss: 2.2992 - val_acc: 0.1794
# Epoch 2/100
# 50000/50000 [==============================] - 7s 140us/step - loss: 2.2964 - acc: 0.1378 - val_loss: 2.2880 - val_acc: 0.2103
# Epoch 3/100
# 50000/50000 [==============================] - 7s 133us/step - loss: 2.2713 - acc: 0.1668 - val_loss: 2.2151 - val_acc: 0.1920
# Epoch 4/100
# 50000/50000 [==============================] - 7s 131us/step - loss: 2.1533 - acc: 0.1839 - val_loss: 2.0631 - val_acc: 0.2131
# Epoch 5/100
# 50000/50000 [==============================] - 7s 136us/step - loss: 2.0794 - acc: 0.1998 - val_loss: 2.0060 - val_acc: 0.2430
# Epoch 6/100
# 50000/50000 [==============================] - 7s 132us/step - loss: 2.0074 - acc: 0.2162 - val_loss: 1.9104 - val_acc: 0.2835
# Epoch 7/100
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.9378 - acc: 0.2434 - val_loss: 1.8358 - val_acc: 0.3024
# Epoch 8/100
# 50000/50000 [==============================] - 7s 133us/step - loss: 1.8738 - acc: 0.2742 - val_loss: 1.7695 - val_acc: 0.3276
# Epoch 9/100
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.8158 - acc: 0.3007 - val_loss: 1.7245 - val_acc: 0.3541
# Epoch 10/100
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.7591 - acc: 0.3330 - val_loss: 1.6508 - val_acc: 0.3846
# Epoch 11/100
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.6972 - acc: 0.3611 - val_loss: 1.5893 - val_acc: 0.4040
# Epoch 12/100
# 50000/50000 [==============================] - 7s 130us/step - loss: 1.6394 - acc: 0.3900 - val_loss: 1.6290 - val_acc: 0.4057
# Epoch 13/100
# 50000/50000 [==============================] - 6s 130us/step - loss: 1.5829 - acc: 0.4147 - val_loss: 1.5035 - val_acc: 0.4465
# Epoch 14/100
# 50000/50000 [==============================] - 7s 131us/step - loss: 1.5425 - acc: 0.4291 - val_loss: 1.5057 - val_acc: 0.4326
# Epoch 15/100
# 50000/50000 [==============================] - 7s 132us/step - loss: 1.4964 - acc: 0.4491 - val_loss: 1.4400 - val_acc: 0.4655
# Epoch 16/100
# 50000/50000 [==============================] - 6s 127us/step - loss: 1.4610 - acc: 0.4617 - val_loss: 1.3921 - val_acc: 0.4882
# Epoch 17/100
# 50000/50000 [==============================] - 6s 130us/step - loss: 1.4267 - acc: 0.4790 - val_loss: 1.3487 - val_acc: 0.5063
# Epoch 18/100
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.3944 - acc: 0.4894 - val_loss: 1.3188 - val_acc: 0.5189
# Epoch 19/100
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.3620 - acc: 0.5028 - val_loss: 1.3281 - val_acc: 0.5110
# Epoch 20/100
# 50000/50000 [==============================] - 6s 122us/step - loss: 1.3377 - acc: 0.5128 - val_loss: 1.2691 - val_acc: 0.5349
# Epoch 21/100
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.3106 - acc: 0.5252 - val_loss: 1.2751 - val_acc: 0.5316
# Epoch 22/100
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.2851 - acc: 0.5351 - val_loss: 1.2204 - val_acc: 0.5607
# Epoch 23/100
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.2588 - acc: 0.5462 - val_loss: 1.2076 - val_acc: 0.5670
# Epoch 24/100
# 50000/50000 [==============================] - 6s 121us/step - loss: 1.2351 - acc: 0.5536 - val_loss: 1.2371 - val_acc: 0.5611
# Epoch 25/100
# 50000/50000 [==============================] - 6s 124us/step - loss: 1.2159 - acc: 0.5634 - val_loss: 1.1827 - val_acc: 0.5676
# Epoch 26/100
# 50000/50000 [==============================] - 7s 135us/step - loss: 1.1934 - acc: 0.5707 - val_loss: 1.1697 - val_acc: 0.5800
# Epoch 27/100
# 50000/50000 [==============================] - 7s 143us/step - loss: 1.1746 - acc: 0.5777 - val_loss: 1.1219 - val_acc: 0.5994
# Epoch 28/100
# 50000/50000 [==============================] - 7s 138us/step - loss: 1.1542 - acc: 0.5847 - val_loss: 1.1144 - val_acc: 0.6012
# Epoch 29/100
# 50000/50000 [==============================] - 7s 142us/step - loss: 1.1357 - acc: 0.5929 - val_loss: 1.1272 - val_acc: 0.5955
# Epoch 30/100
# 50000/50000 [==============================] - 7s 139us/step - loss: 1
# 50000/50000 [==============================] - 6s 121us/step - loss: 0.3781 - acc: 0.8668 - val_loss: 1.0266 - val_acc: 0.7103
# Epoch 99/100
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.3705 - acc: 0.8726 - val_loss: 1.0547 - val_acc: 0.7057
# Epoch 100/100
# 50000/50000 [==============================] - 6s 120us/step - loss: 0.3648 - acc: 0.8720 - val_loss: 1.0313 - val_acc: 0.7083

# %%
y_pred = t.predict(X_test, batch_size=128)

# %%
print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.78      0.74      1000
#            1       0.79      0.84      0.82      1000
#            2       0.61      0.60      0.61      1000
#            3       0.54      0.53      0.54      1000
#            4       0.67      0.67      0.67      1000
#            5       0.64      0.58      0.61      1000
#            6       0.75      0.80      0.77      1000
#            7       0.74      0.75      0.75      1000
#            8       0.86      0.77      0.81      1000
#            9       0.78      0.77      0.77      1000
#
#    micro avg       0.71      0.71      0.71     10000
#    macro avg       0.71      0.71      0.71     10000
# weighted avg       0.71      0.71      0.71     10000

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))

# %%
import pandas as pd
import seaborn as sn

# %%
cm_df = pd.DataFrame(cm, index=[i for i in cifar10_labels.values()], columns = [c for c in cifar10_labels.values()])

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cm_df = pd.DataFrame(cm, index=[i for i in cifar10_labels.values()], columns = [c for c in cifar10_labels.values()])
plt.figure(figsize=(15,10))
sn.heatmap(cm_df, annot=True)
plt.show()

# %%
def output_results(count, model, X_test, y_test, batch_size, label_names=cifar10_labels):
    
    y_pred = model.predict(X_test, batch_size=batch_size)
    # Classification report
    print(len(y_pred))
    # Get random test examples
    list_of_labels = np.random.randint(len(y_pred), size=count)
    plt.figure(figsize=(int(1.5)* count, 2 * count))
    
    for i in np.arange(0,count):
        # Subplot
        plt.subplot(count - 3, 3, i + 1, ymargin=1)
        # Label of the image
        label_as_np_array = y_pred[list_of_labels[i]].argmax()
        plt.title(get_label(label_as_np_array, cifar10_labels))
        # Show the image
        image_to_show = X_test[list_of_labels[i]]
        plt.imshow(image_to_show)
    
    return plt.show()

# %% [markdown]
# ### Another model similar to AlexNet, but without dense layers (Fully Convolutional)

# %% [markdown]
# INPUT => [CONV => RELU => POOL] * 2 => [CONV => RELU] * 3 => POOL => DO => SOFTMAX

# %%
def second_net(batch_size, learning_rate, num_epochs, num_classes, dataset=(X_train, y_train, X_test, y_test)):
    X_train, y_train, X_test, y_test = dataset
    model = Sequential()
    
    # Input => [CONV => RELU => POOL] * 2 => ...
    # First
    model.add(Conv2D(32,(3,3),input_shape = X_train.shape[1:]))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    # Second
    model.add(Conv2D(64,(3,3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2,2)))
    
    # ... => [CONV => RELU] * 3
    # First
    model.add(Conv2D(128, (3,3)))
    model.add(Activation("relu"))
    # Second
    model.add(Conv2D(256, (3,3)))
    model.add(Activation("relu"))

    
    # ... => POOL => ...
    model.add(MaxPooling2D(pool_size=(2,2)))
    # ... => DO => ...
    model.add(Flatten())
    model.add(Dropout(0.5))
    
    # ... => Softmax => Output
    model.add(Dense(num_classes))
    model.add(Activation("softmax"))
    
    # Compile and train the model
    model.compile(loss='categorical_crossentropy',
                  optimizer=SGD(learning_rate),
                  metrics = ["accuracy"])
    
    model.fit(X_train, y_train, 
              batch_size=batch_size, 
              epochs=num_epochs,
              validation_data=(X_test, y_test),
              shuffle=True)
    
    output_results(18, model, X_test, y_test, 128)
    return model

# %%
# %time
t2 = second_net(batch_size=32, learning_rate=0.01, num_epochs=50, num_classes=10, dataset=(X_train, y_train, X_test, y_test))
# Out:
# CPU times: user 7 µs, sys: 0 ns, total: 7 µs
# Wall time: 13.6 µs
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 7s 136us/step - loss: 2
50
# 50000/50000 [==============================] - 7s 139us/step - loss: 0.5535 - acc: 0.8049 - val_loss: 0.8272 - val_acc: 0.7268
# Epoch 35/50
# 50000/50000 [==============================] - 7s 133us/step - loss: 0.5382 - acc: 0.8105 - val_loss: 0.8305 - val_acc: 0.7244
# Epoch 36/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.5195 - acc: 0.8165 - val_loss: 0.8242 - val_acc: 0.7271
# Epoch 37/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.5043 - acc: 0.8220 - val_loss: 0.7987 - val_acc: 0.7356
# Epoch 38/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4887 - acc: 0.8270 - val_loss: 0.8532 - val_acc: 0.7251
# Epoch 39/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4711 - acc: 0.8322 - val_loss: 0.8251 - val_acc: 0.7332
# Epoch 40/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4602 - acc: 0.8370 - val_loss: 0.8317 - val_acc: 0.7345
# Epoch 41/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4480 - acc: 0.8404 - val_loss: 0.8120 - val_acc: 0.7358
# Epoch 42/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4281 - acc: 0.8471 - val_loss: 0.8052 - val_acc: 0.7380
# Epoch 43/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4211 - acc: 0.8511 - val_loss: 0.8193 - val_acc: 0.7363
# Epoch 44/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.4042 - acc: 0.8568 - val_loss: 0.8206 - val_acc: 0.7377
# Epoch 45/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3933 - acc: 0.8616 - val_loss: 0.8344 - val_acc: 0.7449
# Epoch 46/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3801 - acc: 0.8633 - val_loss: 0.8502 - val_acc: 0.7381
# Epoch 47/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3723 - acc: 0.8672 - val_loss: 0.8693 - val_acc: 0.7404
# Epoch 48/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3581 - acc: 0.8709 - val_loss: 0.8687 - val_acc: 0.7426
# Epoch 49/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3499 - acc: 0.8752 - val_loss: 0.8581 - val_acc: 0.7398
# Epoch 50/50
# 50000/50000 [==============================] - 7s 132us/step - loss: 0.3395 - acc: 0.8781 - val_loss: 0.8617 - val_acc: 0.7387
# 10000

# %% [markdown]
# Classification report

# %%
y_pred = t.predict(X_test, batch_size=128)
print(classification_report(y_test.argmax(axis=1), y_pred.argmax(axis=1), target_names=cifar10_labels.values()))
# Out:
#               precision    recall  f1-score   support
#
#     airplane       0.70      0.78      0.74      1000
#   automobile       0.79      0.84      0.82      1000
#         bird       0.61      0.60      0.61      1000
#          cat       0.54      0.53      0.54      1000
#         deer       0.67      0.67      0.67      1000
#          dog       0.64      0.58      0.61      1000
#         frog       0.75      0.80      0.77      1000
#        horse       0.74      0.75      0.75      1000
#         ship       0.86      0.77      0.81      1000
#        truck       0.78      0.77      0.77      1000
#
#    micro avg       0.71      0.71      0.71     10000
#    macro avg       0.71      0.71      0.71     10000
# weighted avg       0.71      0.71      0.71     10000

# %% [markdown]
# Confusion matrix

# %%
confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
# Out:
# array([[784,  32,  47,  17,  22,   2,  11,  13,  36,  36],
#        [ 30, 839,   8,   2,   4,   3,  11,   6,  19,  78],
#        [ 69,  11, 604,  50,  69,  60,  69,  49,  11,   8],
#        [ 27,  14,  72, 531,  61, 146,  69,  45,  10,  25],
#        [ 27,   4,  63,  63, 667,  39,  67,  54,  10,   6],
#        [  9,   8,  78, 187,  47, 578,  20,  62,   4,   7],
#        [  6,   8,  56,  70,  30,  16, 796,   5,   7,   6],
#        [ 20,   2,  33,  35,  79,  54,   6, 748,   3,  20],
#        [112,  40,  11,  13,   9,   2,   7,   7, 766,  33],
#        [ 41,  98,  13,  13,   9,   3,   7,  17,  29, 770]])

# %% [markdown]
# Confusion matrix in the heatmap view

# %%
cm = confusion_matrix(y_test.argmax(axis=1), y_pred.argmax(axis=1))
cm_df = pd.DataFrame(cm, index=[i for i in cifar10_labels.values()], columns = [c for c in cifar10_labels.values()])
plt.figure(figsize=(15,10))
sn.heatmap(cm_df, annot=True)
plt.show()
